# %% [markdown]
# # Day 5

# %% [markdown]
# LIST: Change List Items

# %%
item = ["aakarsh", "ayansh", "sachin"]

# %%
item[1]="anshu"

# %%
item[0:2]=["arshu","ayansh"]

# %%
item
# Out:
# ['arshu', 'ayansh', 'sachin']

# %% [markdown]
# Insert the item in the list

# %%
item.insert(1,"shubham")

# %%
item
# Out:
# ['arshu', 'shubham', 'ayansh', 'sachin']

# %% [markdown]
# Adding items/elements in the list

# %%
item.append("papa")

# %%
item
# Out:
# ['arshu', 'shubham', 'ayansh', 'mama', 'sachin', 'papa']

# %%
#adding two list as one 
element=["houston","katy","boston"]

# %%
item.extend(element)

# %%
item
# Out:
# ['arshu',
#  'shubham',
#  'ayansh',
#  'mama',
#  'sachin',
#  'papa',
#  'houston',
#  'katy',
#  'boston']

# %%
#tuples
item_tuple=("school","collage")
item.extend(item_tuple)

# %%
item
# Out:
# ['arshu',
#  'shubham',
#  'ayansh',
#  'mama',
#  'sachin',
#  'papa',
#  'houston',
#  'katy',
#  'boston',
#  'school',
#  'collage']

# %%
#remove items from list
item.remove("school")

# %%
item
# Out:
# ['arshu',
#  'shubham',
#  'ayansh',
#  'mama',
#  'sachin',
#  'papa',
#  'houston',
#  'katy',
#  'boston',
#  'school']

# %%
item.pop(9)
# Out:
# 'school'

# %%
item
# Out:
# ['arshu',
#  'shubham',
#  'ayansh',
#  'mama',
#  'sachin',
#  'papa',
#  'houston',
#  'katy',
#  'boston']

# %%
item.pop()
# Out:
# 'boston'

# %%
#Deleting the list
del element
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-18ad73cdd840> in <module>
#       1 #Deleting the list
# ----> 2 del element
#
# NameError: name 'element' is not defined

# %%
element
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-7c2186f626d0> in <module>
# ----> 1 element
#
# NameError: name 'element' is not defined

# %%
item.clear()

# %%
del item

# %%
item
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-2d50c3117fbd> in <module>
# ----> 1 item
#
# NameError: name 'item' is not defined

# %%
#loop through the index of the list
item = ["aakarsh", "ayansh", "sachin"]
for if in item:
    print(i)
# Out:
# aakarsh
# ayansh
# sachin

# %%
len(item)
# Out:
# 3

# %%
#iteration
for i in item:
    print(i)
# Out:
# aakarsh
# ayansh
# sachin

# %%
for j in range(len(item)):
    print(item[j])
# Out:
# aakarsh
# ayansh
# sachin

# %%
item.reverse()

# %%
item_copy=item.copy()

# %%
item
# Out:
# ['sachin', 'ayansh', 'aakarsh']

# %%
item_copy
# Out:
# ['sachin', 'ayansh', 'aakarsh']

# %%
a=item

# %%
a
# Out:
# ['sachin', 'ayansh', 'aakarsh']

# %%
#sorting the list
item.sort()

# %%
item
# Out:
# ['aakarsh', 'ayansh', 'sachin']

# %%
item2=["apple,","banana","mango"]

# %%
item3=item+item2

# %%
item3
# Out:
# ['aakarsh', 'ayansh', 'sachin', 'apple,', 'banana', 'mango']

# %% [markdown]
# 1. What’s The Difference Between The Python append() and extend() Methods?
# 2. How To Sort a List?
# 3. How To Concatenate Lists?
# 4. How To Clone Or Copy A List?
# 5. How To Loop over A List?
